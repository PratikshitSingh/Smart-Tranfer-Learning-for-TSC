# %%
from pandas import read_csv
from matplotlib import pyplot
from scipy.stats import pearsonr

# %% [markdown]
# In order to compute the similarities between the datasets,
# we first reduce the number of time series for each dataset
# to one time series (or prototype) per class. The per class
# prototype is computed by averaging the set of time series
# in the corresponding class. We used the well-known DTW
# Barycenter Averaging (DBA) method to the average a set
# of time series [42]. The latter summarizing function was
# proposed and validated as an averaging method in the DTW
# induced space. In addition, DBA has been recently used as a
# data reduction technique where it was evaluated in a nearest
# centroid classification schema [43]. Therefore, to generate the
# similarity matrix between the UCR datasets, we computed a
# distance between each pair of datasets. Finally, for simplicity
# and since the main goal of this paper is not the inter-datasets
# similarity, we chose the distance between two datasets to be
# equal to the minimum distance between the prototypes of their
# corresponding classes

# %% [markdown]
# ##LOAD DATA

# %%
from google.colab import drive
drive.mount('/content/drive/')#Smart-Tranfer-Learning-for-TSC-main/')#UCR_TS_Archive_2015/UCR_TS_Archive_2015/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/My Drive/Smart-Tranfer-Learning-for-TSC-main/UCR_TS_Archive_2015/UCR_TS_Archive_2015/')

# %%
sources = ['Meat/Meat_TRAIN', 'InlineSkate/InlineSkate_TRAIN',   '50words/50words_TRAIN', 'DiatomSizeReduction/DiatomSizeReduction_TRAIN', 'Wine/Wine_TRAIN'] # 'HandOutlines/HandOutlines_TRAIN'
targets = ['Wine/Wine_TRAIN',                 'Meat/Meat_TRAIN',             'DiatomSizeReduction/DiatomSizeReduction_TRAIN', 'InlineSkate/InlineSkate_TRAIN','50words/50words_TRAIN'] # 'ShapeletSim/ShapeletSim_TRAIN'

# %%
sources = ['Beef/Beef_TRAIN', 'RefrigerationDevices/RefrigerationDevices_TRAIN',   'ShapesAll/ShapesAll_TRAIN', 'Adiac/Adiac_TRAIN', 'Wine/Wine_TRAIN', 'UWaveGestureLibraryAll/UWaveGestureLibraryAll_TRAIN', 'MALLAT/MALLAT_TRAIN', 'FaceFour/FaceFour_TRAIN'] # 'HandOutlines/HandOutlines_TRAIN'
targets = ['Meat/Meat_TRAIN',                 'ShapeletSim/ShapeletSim_TRAIN',             'DiatomSizeReduction/DiatomSizeReduction_TRAIN', 'DiatomSizeReduction/DiatomSizeReduction_TRAIN', 'Beef/Beef_TRAIN','Wine/Wine_TRAIN','OliveOil/OliveOil_TRAIN', 'OliveOil/OliveOil_TRAIN'] # 'ShapeletSim/ShapeletSim_TRAIN'

# %% [markdown]
# ## DBA
# Find represntative time series

# %%
# !pip3 install dtaidistance
# !pip3 install tslearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dtaidistance
#   Downloading dtaidistance-2.3.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 49.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from dtaidistance) (1.22.4)
# Installing collected packages: dtaidistance
# Successfully installed dtaidistance-2.3.10
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tslearn
#   Downloading tslearn-0.5.3.2-py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.2/358.2 KB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from tslearn) (1.10.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from tslearn) (1.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from tslearn) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from tslearn) (1.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from tslearn) (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->tslearn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->tslearn) (67.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->tslearn) (3.1.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.5.3.2

# %%
from pandas import read_csv
from matplotlib import pyplot
from dtaidistance import dtw
from tslearn.barycenters import dtw_barycenter_averaging

import numpy as np
import pandas as pd

# %%
def DBA(df_prototype_s, df_prototype_t):
  for i in range(len(df_prototype_s)):
    for j in range(len(df_prototype_t)):
      ts1 = np.array(df_prototype_s.iloc[i])
      ts2 = np.array(df_prototype_t.iloc[j])
      d = dtw.distance_fast(ts1, ts2, use_pruning=True)
      print(d)

# %%
df_prototype_s = {}
df_prototype_t = {}

def generate_prototype(df_source, df_target):
  #df_prototype_s = df_source.groupby(level=0).mean()
  #df_prototype_t = df_target.groupby(level=0).mean()

  for i in range(len(df_source)):
    dfs_class                 = df_source.iloc[i].name
    df_prototype_s[dfs_class] = []

  for i in range(len(df_target)):
    dft_class                 = df_target.iloc[i].name
    df_prototype_t[dft_class] = []

  for i in range(len(df_source)):
    dfs                       = df_source.iloc[i]
    dfs_class                 = df_source.iloc[i].name
    df_prototype_s[dfs_class].append(dfs.to_numpy())

  for i in range(len(df_target)):
    dft                       = df_target.iloc[i]
    dft_class                 = df_target.iloc[i].name
    df_prototype_t[dft_class].append(dft.to_numpy())

  source_barycenters  = {}  # len(df_prototype_s)
  target_barycenters  = {}  # len(df_prototype_t)

  for c in (df_prototype_s.keys()):
    source_barycenters[c] = dtw_barycenter_averaging(df_prototype_s[c])

  for c in (df_prototype_t.keys()):
    target_barycenters[c] = dtw_barycenter_averaging(df_prototype_t[c])

  min_dtw = float("inf")
  min_class = ()

  for i, source_barycenter in source_barycenters.items():
    for j, target_barycenter in target_barycenters.items():
      # Calculate DTW distance
      dtw_distance = dtw.distance(source_barycenter, target_barycenter)

      # Update minimum DTW distance and corresponding class if necessary
      if dtw_distance < min_dtw:
          min_dtw = dtw_distance
          min_class = (i, j)
  print(min_class)
  print(min_dtw)

# %%
for s, t in zip(sources, targets):
  print(s, '-', t)
  df_source = read_csv(s, header=None, index_col=0)
  df_target = read_csv(t, header=None, index_col=0)
  generate_prototype(df_source, df_target)
# Out:
# Meat/Meat_TRAIN - Wine/Wine_TRAIN
# (2, 1)
# 6.5469717781685
# InlineSkate/InlineSkate_TRAIN - Meat/Meat_TRAIN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c73b80466447> in <module>
#       3   df_source = read_csv(s, header=None, index_col=0)
#       4   df_target = read_csv(t, header=None, index_col=0)
# ----> 5   generate_prototype(df_source, df_target)
#
# <ipython-input-15-a3580382d150> in generate_prototype(df_source, df_target)
#      28
#      29   for c in (df_prototype_s.keys()):
# ---> 30     source_barycenters[c] = dtw_barycenter_averaging(df_prototype_s[c])
#      31
#      32   for c in (df_prototype_t.keys()):
#
# /usr/local/lib/python3.9/dist-packages/tslearn/barycenters/dba.py in dtw_barycenter_averaging(X, barycenter_size, init_barycenter, max_iter, tol, weights, metric_params, verbose, n_init)
#     496         if verbose:
#     497             print("Attempt {}".format(i + 1))
# --> 498         bary, loss = dtw_barycenter_averaging_one_init(
#     499             X=X,
#     500             barycenter_size=barycenter_size,
#
# /usr/local/lib/python3.9/dist-packages/tslearn/barycenters/dba.py in dtw_barycenter_averaging_one_init(X, barycenter_size, init_barycenter, max_iter, tol, weights, metric_params, verbose)
#     588     cost_prev, cost = numpy.inf, numpy.inf
#     589     for it in range(max_iter):
# --> 590         list_p_k, cost = _mm_assignment(X_, barycenter, weights, metric_params)
#     591         diag_sum_v_k, list_w_k = _mm_valence_warping(list_p_k, barycenter_size,
#     592                                                      weights)
#
# /usr/local/lib/python3.9/dist-packages/tslearn/barycenters/dba.py in _mm_assignment(X, barycenter, weights, metric_params)
#     212     list_p_k = []
#     213     for i in range(n):
# --> 214         path, dist_i = dtw_path(barycenter, X[i], **metric_params)
#     215         cost += dist_i ** 2 * weights[i]
#     216         list_p_k.append(path)
#
# /usr/local/lib/python3.9/dist-packages/tslearn/metrics/dtw_variants.py in dtw_path(s1, s2, global_constraint, sakoe_chiba_radius, itakura_max_slope)
#     201         sakoe_chiba_radius, itakura_max_slope
#     202     )
# --> 203     acc_cost_mat = njit_accumulated_matrix(s1, s2, mask=mask)
#     204     path = _return_path(acc_cost_mat)
#     205     return path, numpy.sqrt(acc_cost_mat[-1, -1])
#
# /usr/local/lib/python3.9/dist-packages/numba/core/serialize.py in _numba_unpickle(address, bytedata, hashed)
#      27
#      28
# ---> 29 def _numba_unpickle(address, bytedata, hashed):
#      30     """Used by `numba_unpickle` from _helperlib.c
#      31
#
# KeyboardInterrupt:

# %% [markdown]
# ##Pearson Correlation

# %%
def generate_prototype(df_source, df_target, plts):
  #df_prototype_s = df_source.groupby(level=0).mean()
  #df_prototype_t = df_target.groupby(level=0).mean()
  df_prototype_s = {}
  df_prototype_t = {}


  #Equalize lengths
  num_columns = min(len(df_source.columns),len(df_target.columns))
  df_source = df_source.drop(columns=df_source.columns[num_columns:], axis=1)
  df_target = df_target.drop(columns=df_target.columns[num_columns:], axis=1)

  #print(len(df_source.columns),len(df_target.columns))

  for i in range(len(df_source)):
    dfs_class                 = df_source.iloc[i].name
    df_prototype_s[dfs_class] = []

  for i in range(len(df_target)):
    dft_class                 = df_target.iloc[i].name
    df_prototype_t[dft_class] = []

  for i in range(len(df_source)):
    dfs                       = df_source.iloc[i]
    dfs_class                 = df_source.iloc[i].name
    df_prototype_s[dfs_class].append(dfs.to_numpy())

  for i in range(len(df_target)):
    dft                       = df_target.iloc[i]
    dft_class                 = df_target.iloc[i].name
    df_prototype_t[dft_class].append(dft.to_numpy())

  source_barycenters  = {}  # len(df_prototype_s)
  target_barycenters  = {}  # len(df_prototype_t)

  #DBA method to get prototypes
  for c in (df_prototype_s.keys()):
    source_barycenters[c] = dtw_barycenter_averaging(df_prototype_s[c])

  for c in (df_prototype_t.keys()):
    target_barycenters[c] = dtw_barycenter_averaging(df_prototype_t[c])

  max_corr = -float("inf")
  best_class = ()
  for i, source_barycenter in source_barycenters.items():
    for j, target_barycenter in target_barycenters.items():
           
      source_barycenter = np.reshape(source_barycenter,[len(source_barycenter)])
      target_barycenter = np.reshape(target_barycenter,[len(target_barycenter)])
      #Pearson correlation Distance
      #print(len(source_barycenter),len(target_barycenter))
      pearson_corr, _ = pearsonr(source_barycenter, target_barycenter)

      if pearson_corr > max_corr:
          max_corr = pearson_corr
          best_class = (i, j)
  print(best_class)
  print(max_corr)
  plt.figure(plts)
  plt.plot(source_barycenters[i])
  plt.plot(target_barycenters[j])
  return source_barycenters[i], target_barycenters[j]

# %%
plts = 1
import matplotlib.pyplot as plt
for s, t in zip(sources, targets):
  print(s, '-', t)
  df_source = read_csv(s, header=None, index_col=0)
  df_target = read_csv(t, header=None, index_col=0)
  plts+=1
  generate_prototype(df_source, df_target, plts)
# Out:
# Beef/Beef_TRAIN - Meat/Meat_TRAIN
# (3, 2)
# 0.9318838515016191
# RefrigerationDevices/RefrigerationDevices_TRAIN - ShapeletSim/ShapeletSim_TRAIN
# (1, 1)
# 0.08295566149136054
# ShapesAll/ShapesAll_TRAIN - DiatomSizeReduction/DiatomSizeReduction_TRAIN
# (53, 3)
# 0.9295553460476805
# Adiac/Adiac_TRAIN - DiatomSizeReduction/DiatomSizeReduction_TRAIN
# (6, 4)
# 0.19618776506480684
# Wine/Wine_TRAIN - Beef/Beef_TRAIN
# (2, 4)
# -0.15665661422558036
# UWaveGestureLibraryAll/UWaveGestureLibraryAll_TRAIN - Wine/Wine_TRAIN
# (1, 1)
# 0.20295616063479938
# MALLAT/MALLAT_TRAIN - OliveOil/OliveOil_TRAIN
# (3, 2)
# 0.4726448734903869
# FaceFour/FaceFour_TRAIN - OliveOil/OliveOil_TRAIN
# (4, 3)
# 0.00031956598334210214

# %% [markdown]
# ##TLCC

# %%
def generate_prototype(df_source, df_target, plts):
  #df_prototype_s = df_source.groupby(level=0).mean()
  #df_prototype_t = df_target.groupby(level=0).mean()
  df_prototype_s = {}
  df_prototype_t = {}

  #Equalize lengths
  num_columns = min(len(df_source.columns),len(df_target.columns))
  #df_source.drop(columns=df_source.columns[num_columns:], axis=1, inplace=True)
  #df_target.drop(columns=df_target.columns[num_columns:], axis=1, inplace=True)

  for i in range(len(df_source)):
    dfs_class                 = df_source.iloc[i].name
    df_prototype_s[dfs_class] = []

  for i in range(len(df_target)):
    dft_class                 = df_target.iloc[i].name
    df_prototype_t[dft_class] = []

  for i in range(len(df_source)):
    dfs                       = df_source.iloc[i]
    dfs_class                 = df_source.iloc[i].name
    df_prototype_s[dfs_class].append(dfs.to_numpy())

  for i in range(len(df_target)):
    dft                       = df_target.iloc[i]
    dft_class                 = df_target.iloc[i].name
    df_prototype_t[dft_class].append(dft.to_numpy())

  source_barycenters  = {}  # len(df_prototype_s)
  target_barycenters  = {}  # len(df_prototype_t)

  #DBA method to get prototypes
  for c in (df_prototype_s.keys()):
    source_barycenters[c] = dtw_barycenter_averaging(df_prototype_s[c])

  for c in (df_prototype_t.keys()):
    target_barycenters[c] = dtw_barycenter_averaging(df_prototype_t[c])

  max_corr = -float("inf")
  max_corr_argmax = 0
  best_class = ()
  for i, source_barycenter in source_barycenters.items():
    for j, target_barycenter in target_barycenters.items():
           
      source_barycenter = np.reshape(source_barycenter,[len(source_barycenter)])
      target_barycenter = np.reshape(target_barycenter,[len(target_barycenter)])
      #Pearson correlation Distance
      pearson_corr = sm.tsa.stattools.ccf(source_barycenter, target_barycenter, adjusted=False)
      
      if pearson_corr.max() > max_corr:
          max_corr = pearson_corr.max()
          max_corr_argmax = pearson_corr.argmax()
          best_class = (i, j)
  print(best_class)
  print("Max TLCC correlation" , max_corr)
  print(max_corr_argmax)
  plt.figure(plts)
  plt.plot(source_barycenters[i])
  plt.plot(target_barycenters[j])
  plt.plot(max_corr_argmax, source_barycenters[i][max_corr_argmax], marker="o", markersize=10, markeredgecolor="red", markerfacecolor="red")
  #plt.plot((max_corr_argmax, source_barycenters[i][max_corr_argmax]))
  #plt.plot((max_corr_argmax, target_barycenters[j][max_corr_argmax]))
  return source_barycenters[i], target_barycenters[j]

# %%
plts = 1
import matplotlib.pyplot as plt
for s, t in zip(sources, targets):
  print(s, '-', t)
  df_source = read_csv(s, header=None, index_col=0)
  df_target = read_csv(t, header=None, index_col=0)
  plts+=1
  generate_prototype(df_source, df_target, plts)
# Out:
# Beef/Beef_TRAIN - Meat/Meat_TRAIN
# (3, 1)
# Max TLCC correlation 0.7446317767952724
# 0
# RefrigerationDevices/RefrigerationDevices_TRAIN - ShapeletSim/ShapeletSim_TRAIN
# (2, 1)
# Max TLCC correlation 0.08572260795206378
# 132
# ShapesAll/ShapesAll_TRAIN - DiatomSizeReduction/DiatomSizeReduction_TRAIN
# (17, 2)
# Max TLCC correlation 0.35519303388591517
# 244
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-46bb8f8188a0> in <module>
#       6   df_target = read_csv(t, header=None, index_col=0)
#       7   plts+=1
# ----> 8   generate_prototype(df_source, df_target, plts)
#       9
#
# <ipython-input-34-8408ef43a7b7> in generate_prototype(df_source, df_target, plts)
#      59   plt.plot(source_barycenters[i])
#      60   plt.plot(target_barycenters[j])
# ---> 61   plt.plot(max_corr_argmax, source_barycenters[i][max_corr_argmax], marker="o", markersize=10, markeredgecolor="red", markerfacecolor="red")
#      62   #plt.plot((max_corr_argmax, source_barycenters[i][max_corr_argmax]))
#      63   #plt.plot((max_corr_argmax, target_barycenters[j][max_corr_argmax]))
#
# IndexError: index 244 is out of bounds for axis 0 with size 176

# %% [markdown]
# The red point shows the point from which maximum correlation is observed

# %%
import statsmodels.api as sm

#calculate cross correlation
tlcc = sm.tsa.stattools.ccf(df1.iloc[1], df2.iloc[1], adjusted=False)

# %%
tlcc
# Out:
# array([0.24409428, 0.24498763, 0.24584897, ..., 0.00219568, 0.0014916 ,
#        0.00073137])

# %%
tlcc.max()
# Out:
# 0.48980435974594594

# %%
tlcc.argmax()
# Out:
# 199

# %% [markdown]
# We offset the entire datasets by 1029 for training

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(tlcc)

# %% [markdown]
# ## Visualization

# %%
df1
# Out:
#         1         2         3         4         5         6         7     \
# 0
# 2  -0.036166 -0.151640 -0.089001 -0.133280 -0.077171 -0.117890 -0.081651
# 2  -0.554270 -0.593670 -0.579670 -0.602390 -0.604810 -0.601310 -0.604460
# 3   0.149520  0.026359  0.167520  0.054150  0.092847  0.085971  0.109040
# 7  -0.363130 -0.646230 -0.693990 -0.515550 -0.631540 -0.628680 -0.601330
# 6   0.090731 -0.092733 -0.026174 -0.064635 -0.089953 -0.062950 -0.079535
# ..       ...       ...       ...       ...       ...       ...       ...
# 3  -0.109750 -0.234050 -0.147190 -0.234710 -0.194010 -0.236220 -0.213820
# 6   0.127900 -0.000188  0.031357  0.107760  0.048947  0.080089  0.105490
# 6  -0.729890 -0.902960 -0.775570 -0.863180 -0.837530 -0.813620 -0.840030
# 6   0.042380 -0.122540 -0.137170 -0.035629 -0.114190 -0.092562 -0.054051
# 1   0.160030 -0.263190 -0.265790 -0.078592 -0.249220 -0.172170 -0.156720
#
#         8         9         10    ...      1873      1874      1875      1876  \
# 0                                 ...
# 2  -0.092772 -0.093733 -0.086446  ... -0.140390 -0.152270 -0.183840 -0.165660
# 2  -0.632650 -0.620530 -0.630410  ... -0.466000 -0.462560 -0.492210 -0.469990
# 3   0.105860  0.105700  0.107180  ...  0.407590  0.401730  0.413610  0.418240
# 7  -0.651290 -0.617220 -0.612940  ... -0.451170 -0.436120 -0.433550 -0.452010
# 6  -0.083377 -0.101650 -0.109250  ... -0.050490 -0.049658 -0.062375 -0.073720
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 3  -0.228060 -0.248190 -0.259780  ... -0.541170 -0.547200 -0.562610 -0.557520
# 6   0.073951  0.070994  0.064312  ...  0.054495  0.049642  0.068174  0.066708
# 6  -0.840140 -0.850770 -0.848230  ... -0.604730 -0.591820 -0.592820 -0.617410
# 6  -0.098257 -0.092949 -0.068555  ... -0.366270 -0.350480 -0.363710 -0.394490
# 1  -0.264860 -0.203740 -0.159310  ...  4.076200  4.117300  4.128500  4.175800
#
#         1877      1878      1879     1880      1881      1882
# 0
# 2  -0.149100 -0.155760 -0.180100 -0.12786 -0.192020 -0.110380
# 2  -0.495640 -0.493980 -0.531910 -0.49810 -0.537830 -0.517410
# 3   0.401960  0.404070  0.403470  0.37642  0.367230  0.409760
# 7  -0.404250 -0.458800 -0.524100 -0.41348 -0.552420 -0.562540
# 6  -0.097504 -0.103050 -0.082875 -0.14308 -0.078123 -0.142350
# ..       ...       ...       ...      ...       ...       ...
# 3  -0.548480 -0.581820 -0.573110 -0.55364 -0.628800 -0.523310
# 6   0.074728  0.075721  0.054056  0.11070  0.090602  0.052547
# 6  -0.615490 -0.621520 -0.584290 -0.61942 -0.581230 -0.604630
# 6  -0.354260 -0.370130 -0.411340 -0.31616 -0.380740 -0.399600
# 1   4.223900  4.218500  4.228600  4.30010  4.339300  4.319000
#
# [100 rows x 1882 columns]

# %%
df1.loc[2]
# Out:
#        1         2         3        4         5         6         7     \
# 0
# 2 -0.036166 -0.151640 -0.089001 -0.13328 -0.077171 -0.117890 -0.081651
# 2 -0.554270 -0.593670 -0.579670 -0.60239 -0.604810 -0.601310 -0.604460
# 2 -0.474410 -0.817140 -0.554510 -0.70125 -0.647080 -0.678700 -0.689580
# 2 -0.606260 -0.746320 -0.666570 -0.72195 -0.672380 -0.694610 -0.707680
# 2  0.585310  0.537880  0.570570  0.53082  0.585530  0.531840  0.571210
# 2 -0.369320 -0.689330 -0.452450 -0.62404 -0.561880 -0.562580 -0.602000
# 2  0.322010  0.310640  0.321180  0.29116  0.283110  0.302470  0.307120
# 2 -0.402870 -0.747820 -0.527440 -0.68560 -0.596780 -0.585870 -0.620460
# 2 -0.004913 -0.080048 -0.035154 -0.09727 -0.055195 -0.068475 -0.077105
# 2 -0.594870 -0.852690 -0.966630 -0.71533 -0.810590 -0.869610 -0.788210
# 2 -0.315130 -0.387330 -0.329290 -0.42112 -0.387780 -0.422640 -0.413080
# 2 -0.699930 -0.807510 -0.702980 -0.77703 -0.712720 -0.748080 -0.722980
# 2 -0.394680 -0.422410 -0.418300 -0.43057 -0.421380 -0.427220 -0.424130
# 2  0.383110  0.259520  0.199910  0.30256  0.259370  0.244750  0.288090
#
#        8         9         10    ...     1873     1874      1875     1876  \
# 0                                ...
# 2 -0.092772 -0.093733 -0.086446  ... -0.14039 -0.15227 -0.183840 -0.16566
# 2 -0.632650 -0.620530 -0.630410  ... -0.46600 -0.46256 -0.492210 -0.46999
# 2 -0.665330 -0.698670 -0.684370  ... -0.44983 -0.47576 -0.460780 -0.47893
# 2 -0.740820 -0.712720 -0.728800  ... -0.52266 -0.51290 -0.537470 -0.53891
# 2  0.556600  0.537400  0.572720  ... -0.12763 -0.12685 -0.095703 -0.12915
# 2 -0.568010 -0.578450 -0.600270  ... -0.35515 -0.30914 -0.306680 -0.33956
# 2  0.294820  0.280610  0.304080  ...  0.49557  0.49182  0.483790  0.49300
# 2 -0.596600 -0.623120 -0.650760  ... -0.73863 -0.74539 -0.747980 -0.75178
# 2 -0.093561 -0.094781 -0.109120  ... -0.27678 -0.26595 -0.260400 -0.26741
# 2 -0.855050 -0.883400 -0.847930  ...  3.30550  3.30230  3.315700  3.32690
# 2 -0.418190 -0.421830 -0.437450  ...  0.42200  0.41627  0.421140  0.41190
# 2 -0.761760 -0.737530 -0.714900  ... -0.61608 -0.63829 -0.616770 -0.59266
# 2 -0.443330 -0.484330 -0.436590  ...  0.61971  0.64148  0.614780  0.61987
# 2  0.259290  0.248340  0.267420  ...  2.08090  2.09310  2.088800  2.08060
#
#       1877     1878     1879      1880     1881      1882
# 0
# 2 -0.14910 -0.15576 -0.18010 -0.127860 -0.19202 -0.110380
# 2 -0.49564 -0.49398 -0.53191 -0.498100 -0.53783 -0.517410
# 2 -0.46080 -0.52768 -0.48762 -0.545520 -0.50410 -0.484760
# 2 -0.53150 -0.51295 -0.56033 -0.510800 -0.56690 -0.478890
# 2 -0.13467 -0.11080 -0.11060 -0.081575 -0.16145 -0.074976
# 2 -0.32637 -0.36656 -0.33142 -0.431870 -0.38239 -0.350110
# 2  0.46733  0.45871  0.44554  0.461830  0.44243  0.465050
# 2 -0.73235 -0.78023 -0.72569 -0.803230 -0.75721 -0.753560
# 2 -0.29044 -0.27732 -0.29036 -0.278210 -0.33261 -0.266260
# 2  3.32300  3.33580  3.32500  3.284000  3.30650  3.346300
# 2  0.39807  0.41874  0.40449  0.417560  0.38368  0.434930
# 2 -0.60333 -0.59845 -0.61826 -0.610510 -0.66297 -0.560030
# 2  0.61502  0.59495  0.58213  0.599710  0.57695  0.567070
# 2  2.08140  2.07710  2.06950  2.075200  2.08410  2.080600
#
# [14 rows x 1882 columns]

# %%
df1_2 = df1.loc[2]
df1_1 = df1.loc[1]
df1_3 = df1.loc[3]

# %%
for i in range(4):
    ts = df1_2.iloc[i]
    ts = ts.cumsum()
    ts.plot(color = 'b', label = 'class 2', use_index=True)

for i in range(4):
    ts = df1_3.iloc[i]
    ts = ts.cumsum()
    ts.plot(color = 'r', label = 'class 1')

for i in range(4):
    ts = df1_1.iloc[i]
    ts = ts.cumsum()
    ts.plot(color = 'g', label = 'class 1')

# %%
df2
# Out:
#       1       2       3       4       5       6       7       8       9     \
# 0
# 1  -2.3312 -2.3312 -2.3356 -2.3400 -2.3443 -2.3465 -2.3465 -2.3465 -2.3464
# 1  -2.3374 -2.3374 -2.3374 -2.3374 -2.3397 -2.3397 -2.3397 -2.3397 -2.3397
# 0  -2.3414 -2.3436 -2.3458 -2.3546 -2.3568 -2.3590 -2.3590 -2.3590 -2.3590
# 1  -2.3892 -2.3892 -2.3892 -2.3892 -2.3892 -2.3892 -2.3914 -2.3914 -2.3890
# 1  -2.3643 -2.3643 -2.3665 -2.3709 -2.3753 -2.3753 -2.3753 -2.3731 -2.3708
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 0  -2.3619 -2.3619 -2.3619 -2.3619 -2.3619 -2.3642 -2.3642 -2.3641 -2.3640
# 1  -2.3482 -2.3482 -2.3482 -2.3482 -2.3482 -2.3507 -2.3507 -2.3507 -2.3507
# 1  -2.1880 -2.1905 -2.1905 -2.1905 -2.1905 -2.1905 -2.1905 -2.1905 -2.1905
# 0  -2.1700 -2.1700 -2.1700 -2.1700 -2.1700 -2.1700 -2.1700 -2.1700 -2.1700
# 1  -2.3457 -2.3457 -2.3457 -2.3457 -2.3507 -2.3507 -2.3507 -2.3532 -2.3532
#
#       10    ...     1873     1874     1875     1876     1877     1878  \
# 0           ...
# 1  -2.3461  ...  1.35810  1.34980  1.34110  1.34010  1.33460  1.32600
# 1  -2.3395  ...  0.86990  0.86069  0.85148  0.84398  0.83477  0.82786
# 0  -2.3588  ...  1.19210  1.18330  1.17460  1.16580  1.15710  1.15060
# 1  -2.3908  ...  1.19720  1.18970  1.18110  1.17250  1.16390  1.15480
# 1  -2.3706  ...  1.12240  1.11330  1.10470  1.09650  1.08740  1.07880
# ..     ...  ...      ...      ...      ...      ...      ...      ...
# 0  -2.3637  ...  1.26220  1.25320  1.24420  1.23520  1.22620  1.21730
# 1  -2.3504  ...  1.18510  1.17790  1.16820  1.15860  1.15130  1.14170
# 1  -2.1905  ...  0.81062  0.80514  0.79826  0.79085  0.78343  0.77602
# 0  -2.1700  ...  0.48527  0.47760  0.47250  0.46484  0.45718  0.44952
# 1  -2.3530  ...  1.17100  1.16110  1.15370  1.14380  1.13840  1.13420
#
#        1879     1880     1881     1882
# 0
# 1   1.31760  1.30900  1.30040  1.29170
# 1   0.81866  0.81175  0.80255  0.79334
# 0   1.14920  1.14830  1.13950  1.13080
# 1   1.14400  1.13540  1.12850  1.12410
# 1   1.07020  1.06160  1.05290  1.04430
# ..      ...      ...      ...      ...
# 0   1.20600  1.19700  1.19110  1.18960
# 1   1.13210  1.12480  1.11520  1.10800
# 1   0.77108  0.76367  0.75626  0.74885
# 0   0.44186  0.43420  0.42910  0.42145
# 1   1.13090  1.12100  1.11360  1.10370
#
# [370 rows x 1882 columns]

# %%
df1_2 = df2.loc[0]
df1_1 = df2.loc[1]

# %%
for i in range(4):
    ts = df1_2.iloc[i]
    ts = ts.cumsum()
    ts.plot(color = 'b', label = 'class 2', use_index=True)

for i in range(4):
    ts = df1_1.iloc[i]
    ts = ts.cumsum()
    ts.plot(color = 'r', label = 'class 1')

# %% [markdown]
# # New Section

# %%
df1
# Out:
#         1         2         3         4         5         6         7     \
# 0
# 2  -0.036166 -0.151640 -0.089001 -0.133280 -0.077171 -0.117890 -0.081651
# 2  -0.554270 -0.593670 -0.579670 -0.602390 -0.604810 -0.601310 -0.604460
# 3   0.149520  0.026359  0.167520  0.054150  0.092847  0.085971  0.109040
# 7  -0.363130 -0.646230 -0.693990 -0.515550 -0.631540 -0.628680 -0.601330
# 6   0.090731 -0.092733 -0.026174 -0.064635 -0.089953 -0.062950 -0.079535
# ..       ...       ...       ...       ...       ...       ...       ...
# 3  -0.109750 -0.234050 -0.147190 -0.234710 -0.194010 -0.236220 -0.213820
# 6   0.127900 -0.000188  0.031357  0.107760  0.048947  0.080089  0.105490
# 6  -0.729890 -0.902960 -0.775570 -0.863180 -0.837530 -0.813620 -0.840030
# 6   0.042380 -0.122540 -0.137170 -0.035629 -0.114190 -0.092562 -0.054051
# 1   0.160030 -0.263190 -0.265790 -0.078592 -0.249220 -0.172170 -0.156720
#
#         8         9         10    ...      1873      1874      1875      1876  \
# 0                                 ...
# 2  -0.092772 -0.093733 -0.086446  ... -0.140390 -0.152270 -0.183840 -0.165660
# 2  -0.632650 -0.620530 -0.630410  ... -0.466000 -0.462560 -0.492210 -0.469990
# 3   0.105860  0.105700  0.107180  ...  0.407590  0.401730  0.413610  0.418240
# 7  -0.651290 -0.617220 -0.612940  ... -0.451170 -0.436120 -0.433550 -0.452010
# 6  -0.083377 -0.101650 -0.109250  ... -0.050490 -0.049658 -0.062375 -0.073720
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 3  -0.228060 -0.248190 -0.259780  ... -0.541170 -0.547200 -0.562610 -0.557520
# 6   0.073951  0.070994  0.064312  ...  0.054495  0.049642  0.068174  0.066708
# 6  -0.840140 -0.850770 -0.848230  ... -0.604730 -0.591820 -0.592820 -0.617410
# 6  -0.098257 -0.092949 -0.068555  ... -0.366270 -0.350480 -0.363710 -0.394490
# 1  -0.264860 -0.203740 -0.159310  ...  4.076200  4.117300  4.128500  4.175800
#
#         1877      1878      1879     1880      1881      1882
# 0
# 2  -0.149100 -0.155760 -0.180100 -0.12786 -0.192020 -0.110380
# 2  -0.495640 -0.493980 -0.531910 -0.49810 -0.537830 -0.517410
# 3   0.401960  0.404070  0.403470  0.37642  0.367230  0.409760
# 7  -0.404250 -0.458800 -0.524100 -0.41348 -0.552420 -0.562540
# 6  -0.097504 -0.103050 -0.082875 -0.14308 -0.078123 -0.142350
# ..       ...       ...       ...      ...       ...       ...
# 3  -0.548480 -0.581820 -0.573110 -0.55364 -0.628800 -0.523310
# 6   0.074728  0.075721  0.054056  0.11070  0.090602  0.052547
# 6  -0.615490 -0.621520 -0.584290 -0.61942 -0.581230 -0.604630
# 6  -0.354260 -0.370130 -0.411340 -0.31616 -0.380740 -0.399600
# 1   4.223900  4.218500  4.228600  4.30010  4.339300  4.319000
#
# [100 rows x 1882 columns]
